# %%
# Задание на 8 баллов

print('Добрый день!\n')
print('Это бот по подбору фильмов для уютного семейного вечера. Скажите, пожалуйста, вы хотите посмотреть фильм или мультфильм?')

answer = input() # сюда сохраняем ответ пользователя


if answer == 'фильм' or answer == 'Фильм':
  print('Хороший выбор! Фильм какого жанра вы хотели бы посмотреть? Мы можем предложить боевик, вестерн, детектив, исторический и фэнтези. Если не знаете, то напишите: "Не знаю".')
  answer = input()
  if answer == 'боевик' or answer == 'Боевик':
    print('Мы думаем, вам стоит посмотреть Форсаж')
  elif answer == 'вестерн' or answer == 'Вестерн':
    print('Мы думаем, вам стоит посмотреть Дикого Билла')
  elif answer == 'детектив' or answer == 'Детектив':
    print('Мы думаем, вам стоит посмотреть Шерлока Холмса')
  elif answer == 'исторический' or answer == 'Исторический':
    print('Мы думаем, вам стоит посмотреть Союз спасения')
  elif answer == 'фэнтези' or answer == 'Фэнтези' or answer == 'фентези' or answer == 'Фентези':
    print('Мы думаем, вам стоит посмотреть Властелина колец')
  elif answer == 'Не знаю' or answer == 'не знаю':
    print('Мы думаем, вам стоит посмотреть Властелина колец')
  print('Спасибо, что выбрали именно нас!')

elif answer =='мультфильм' or  answer == 'Мультфильм':
  print('Хороший выбор! Вы хотите мультфильм от Диснея или про Барби?')
  answer = input()
  if answer == 'от Диснея' or answer == 'Дисней' or answer == 'дисней' or answer ==  'от диснея':
    print('Мы думаем, вам стоит посмотреть Холодное сердце')
  elif answer == 'про Барби' or answer == 'про барби' or answer ==  'Барби' or answer ==  'барби':
    print('Мы думаем, вам стоит посмотреть Барби: Приключения русалочки')
  print('Спасибо, что выбрали именно нас!')

elif answer == 'Не знаю' or answer == 'не знаю':
  print('Чтобы мы могли вам подсказать, вам необходимо определиться :) \nПерезапустите меня, пожалуйста, и укажите свой выбор.')

else:
  print('Я вас не понимаю. Перезапустите меня, пожалуйста, и укажите, что вы хотели бы посмотреть')
